# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
import pandas as pd

url = "https://kr.trip.com/things-to-do/detail/15931035"
page = urlopen(url)
soup = BeautifulSoup(page, 'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="ko-KR">\n <head>\n  <meta content="IE=edge" http-equiv="X-UA-Compatible"/>\n  <title>\n   홍콩 피크 트램 + 스카이테라스 428 입장권 | Trip.com\n  </title>\n  <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no" name="viewport"/>\n  <meta content="text/html; charset=UTF-8" name="content-type"/>\n  <link href="https://www.trip.com/trip.ico" rel="SHORTCUT ICON" type="image/x-icon"/>\n  <link href="https://www.trip.com/trip.ico" rel="ICON"/>\n  <link href="https://kr.trip.com/things-to-do/detail/15931035/" hreflang="ko" rel="alternate"/>\n  <link href="https://hk.trip.com/things-to-do/detail/15931035/" hreflang="zh-Hant-HK" rel="alternate"/>\n  <link href="https://uk.trip.com/things-to-do/detail/15931035/" hreflang="en-GB" rel="alternate"/>\n  <link href="https://sg.trip.com/things-to-do/detail/15931035/" hreflang="en-SG" rel="alternate"/>\n  <link href="https://my.trip.com/things-to-do/detail/15931035/" hreflang="ms" rel="alternate"/>\n  <link href="https://au.trip.com/things-to-do/detail/15931035/" hreflang="en-AU" rel="alternate"/>\n  <link href="https://www.trip.com/things-to-do/detail/15931035/" hreflang="x-default" rel="alternate"/>\n  <link href="https://kr.trip.com/things-to-do/detail/15931035/" rel="canonical"/>\n  <link href="//webresource.english.c-ctrip.com/resaresenglish/ibu/fe-common/css/global-s.a49b3e0a.css" rel="stylesheet" type="text/css"/>\n  <link href="//webresource.english.c-ctrip.com/resaresenglish/ibu/fe-common/css/lang-kr.e690c0e5.css" rel="stylesheet" type="text/css"/>\n  <link href="https://webresource.english.c-ctrip.com/ares2/activity/ottd-online-international-website-application/2.11.3/default/_next/static/detail/index.css" rel="stylesheet"/>\n </head>\n <body class="ko-KR">\n  <div class="ottd-header">\n   <script type="text/javascript">\n    try {\n    var __SITE_CONFIG__ = {};\n    var __HEAD_CONFIG__ = {\n        site : \'KR\',\n        group : \'trip\',\n        locale : \'ko_kr\',\n        channel : \'ttd\',\n        language : \'KR\',\n        currency : \'KRW\',\n        servername : \'kr.trip.com\',\n        cookiedomain : \'trip.com\'\n    };\n    __SITE_CONFIG__.accountdomain = \'https://www.trip.com/global/kr/\';\n    __HEAD_CONFIG__._new_account_flag = \'1\';\n    __HEAD_CONFIG__._new_order_link_flag = \'1\';\n    __HEAD_CONFIG__._show_language = \'1\';\n    __HEAD_CONFIG__._show_login_auto = \'0\';\n    __HEAD_CONFIG__._simple_head = \'0\';\n    __HEAD_CONFIG__._live_chat_url_pro = \'http://livechat.trip.com/livechat/login.aspx\';\n    __HEAD_CONFIG__._live_chat_url_fat = \'http://livechat.trip.com/livechat/login.aspx\';\n    __HEAD_CONFIG__._live_chat_url_pro_new = \'https://kefu.trip.com/im/\';\n    __HEAD_CONFIG__._live_chat_url_fat_new = \'https://kefu.trip.com/im/\';\n    __HEAD_CONFIG__._header_point_flag = \'1\';\n    __HEAD_CONFIG__._header_collect_flag = \'1\';\n    __HEAD_CONFIG__._header_new_booking = \'1\';\n    __HEAD_CONFIG__._header_new_profile = \'1\';\n    __HEAD_CONFIG__._new_live_chat_flag = \'1\';\n    __HEAD_CONFIG__._header_promo_code_flag = \'1\';\n    __HEAD_CONFIG__._header_tier_points_flag = \'1\';\n\n    __HEAD_CONFIG__._live_chat = 1;\n    __HEAD_CONFIG__._union_cookie = 1;\n    __HEAD_CONFIG__._header_nocomponents = \'0\';\n    __HEAD_CONFIG__._header_use_externaljs= \'0\';\n\n    __HEAD_CONFIG__.regionsData = [{"domain":"www.trip.com","icon":"flag-xx","language":"EN","languageName":"English","locale":"en_xx","site":"EN"},{"domain":"us.trip.com","icon":"flag-us","language":"EN","languageName":"English&nbsp;(United States)","locale":"en_us","site":"US"},{"domain":"uk.trip.com","icon":"flag-uk","language":"EN","languageName":"English&nbsp;(United Kingdom)","locale":"en_gb","site":"GB"},{"domain":"hk.trip.com","icon":"flag-hk","language":"HK","languageName":"繁體中文&nbsp;(香港)","locale":"zh_hk","site":"HK"},{"domain":"hk.trip.com","icon":"flag-hk","language":"EN","languageName":"English&nbsp;(Hong Kong)","locale":"en_hk", ...

# %%
from bs4 import BeautifulSoup
from urlib.request import urlopen
import pandas as pd
