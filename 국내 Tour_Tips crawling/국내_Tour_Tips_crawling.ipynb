# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "http://www.tourtips.com/ap/tboard/tour_talk/?q=%EC%9D%B4%ED%83%88%EB%A6%AC%EC%95%84&k=0&ps=20&pf="
page = urlopen(url)

soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script type="text/javascript">
# ...

# %%
url_base = "http://www.tourtips.com/ap/tboard/tour_talk/?q=%EC%9D%B4%ED%83%88%EB%A6%AC%EC%95%84&k=0&ps=20&pf="
url_sub = "#subWrap > div.contents > div.noticeListWrap > table > tbody > tr:nth-child(1) > td.mrgnLeft0 > a"
url = url_base + url_sub

html = urlopen(url)
soup = BeautifulSoup(html, "html.parser")

soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# ...

# %%
print(soup.find_all('a'))
# Out:
# [<a href="#container" onclick="document.getElementById('container').focus();return false;">컨텐츠 바로가기</a>, <a href="http://www.tourtips.com">
# <img alt="투어팁스" src="//img.tourtips.com/images/pc/logo/origin.gif"/>
# ...

# %%
len(soup.find_all('a'))
# Out:
# 153

# %%
len(soup.find_all('div'))
# Out:
# 59

# %%
temp = soup.find_all('a')[0]
type(temp)
# Out:
# bs4.element.Tag

# %%
temp.find(class_='a')

# %%
rank = []
title = []
content = []
url_add = []

list_soup = soup.find_all('a', 'div')
