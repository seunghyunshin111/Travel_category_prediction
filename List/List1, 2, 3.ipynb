# %%
import operator
x = {'로마': 521, '밀라노': 223, '나폴리': 58, '팔레르모': 7, '토리노': 10, '바리': 4, '카타니아': 3, '볼로냐': 13, '피렌체': 405, '베네치아': 143, '칼리아리': 1, '베로나': 50, '파도바': 5, '모데나': 1, '파르마': 1, '페루자': 1, '라벤나': 2, '베르가모': 5, '라티나': 4, '노바라': 1, '라스페치아': 10}

List1 = sorted(x.items(), key = operator.itemgetter(1), reverse=True)
List1
# Out:
# [('로마', 521),
#  ('피렌체', 405),
#  ('밀라노', 223),
#  ('베네치아', 143),
#  ('나폴리', 58),
#  ('베로나', 50),
#  ('볼로냐', 13),
#  ('토리노', 10),
#  ('라스페치아', 10),
#  ('팔레르모', 7),
#  ('파도바', 5),
#  ('베르가모', 5),
#  ('바리', 4),
#  ('라티나', 4),
#  ('카타니아', 3),
#  ('라벤나', 2),
#  ('칼리아리', 1),
#  ('모데나', 1),
#  ('파르마', 1),
#  ('페루자', 1),
#  ('노바라', 1)]

# %%
y = {'rome': 28191, 'milan': 10163, 'naples': 8899, 'turin': 1152, 'palermo': 3743, 'genoa': 1138, 'bologna': 2981, 'florence': 17927, 'bari': 1440, 'catania': 2067, 'venice': 18563, 'verona': 2824, 'messina': 362, 'padua': 350, 'trieste': 653, 'brescia': 365, 'taranto': 134, 'parma': 548, 'prato': 104, 'modena': 451, 'reggio calabria': 42, 'reggio emilia': 22, 'perugia': 1227, 'livorno': 205, 'ravenna': 860, 'cagliari': 429, 'foggia': 78, 'rimini': 330, 'salerno': 1066, 'ferrara': 421, 'sassari': 81, 'latina': 74, 'giugliano in campania': 0, 'monza': 62, 'syracuse': 243, 'bergamo': 1238, 'pescara': 194, 'trento': 278, 'forlì': 0, 'vicenza': 436, 'terni': 200, 'bolzano': 741, 'novara': 52, 'piacenza': 51, 'ancona': 476, 'andria': 43, 'udine': 119, 'arezzo': 410, 'cesena': 47, 'lecce': 928, 'pesaro': 64, 'barletta': 15, 'alessandria': 20, 'la spezia': 1316, 'pistoia': 142, 'pisa': 5074, 'catanzaro': 16, 'guidonia montecelio': 0, 'lucca': 3257, 'brindisi': 359, 'torre del greco': 1, 'treviso': 392, 'busto arsizio': 7, 'como': 3579, 'marsala': 158, 'grosseto': 141, 'sesto san giovanni': 2, 'pozzuoli': 71, 'varese': 74, 'fiumicino': 731, 'casoria': 0, 'asti': 2095, 'cinisello balsamo': 0, 'caserta': 205, 'gela': 569, 'aprilia': 0, 'ragusa': 486, 'pavia': 112, 'cremona': 136, 'carpi': 9, "quartu sant'elena": 0, 'lamezia terme': 10, 'altamura': 23, 'imola': 16, 'l’aquila': 0, 'massa': 148, 'trapani': 919, 'viterbo': 314, 'cosenza': 46, 'potenza': 54, 'castellammare di stabia': 5, 'afragola': 0, 'vittoria': 81, 'crotone': 3, 'pomezia': 3, 'vigevano': 28, 'carrara': 75, 'caltanissetta': 11, 'viareggio': 232, 'fano': 160, 'savona': 64, 'matera': 1004, 'olbia': 283, 'legnano': 4, 'acerra': 0, 'marano di napoli': 0, 'benevento': 24, 'molfetta': 6, 'agrigento': 815, 'faenza': 64, 'cerignola': 0, 'moncalieri': 0, 'foligno': 97, 'manfredonia': 22, 'tivoli': 274, 'cuneo': 53, 'trani': 287, 'bisceglie': 10, 'bitonto': 1, 'bagheria': 14, 'anzio': 95, 'portici': 7, 'modica': 256, 'sanremo': 39, 'avellino': 12, 'teramo': 28, 'montesilvano': 0, 'siena': 5382, 'gallarate': 88, 'velletri': 4, "cava de' tirreni": 2, 'san severo': 10, 'aversa': 10, 'ercolano': 199, 'civitavecchia': 337, 'acireale': 33, 'mazara del vallo': 19, 'rovigo': 18, 'pordenone': 24, 'battipaglia': 11, 'rho': 939, 'chieti': 23, 'scafati': 1, 'scandicci': 8}

List2 = sorted(y.items(), key = operator.itemgetter(1), reverse=True)
List2
# Out:
# [('rome', 28191),
#  ('venice', 18563),
#  ('florence', 17927),
#  ('milan', 10163),
#  ('naples', 8899),
#  ('siena', 5382),
#  ('pisa', 5074),
#  ('palermo', 3743),
#  ('como', 3579),
#  ('lucca', 3257),
#  ('bologna', 2981),
#  ('verona', 2824),
#  ('asti', 2095),
#  ('catania', 2067),
#  ('bari', 1440),
#  ('la spezia', 1316),
#  ('bergamo', 1238),
#  ('perugia', 1227),
#  ('turin', 1152),
#  ('genoa', 1138),
#  ('salerno', 1066),
#  ('matera', 1004),
#  ('rho', 939),
#  ('lecce', 928),
#  ('trapani', 919),
#  ('ravenna', 860),
#  ('agrigento', 815),
#  ('bolzano', 741),
#  ('fiumicino', 731),
#  ('trieste', 653),
#  ('gela', 569),
#  ('parma', 548),
#  ('ragusa', 486),
#  ('ancona', 476),
#  ('modena', 451),
#  ('vicenza', 436),
#  ('cagliari', 429),
#  ('ferrara', 421),
#  ('arezzo', 410),
#  ('treviso', 392),
#  ('brescia', 365),
#  ('messina', 362),
#  ('brindisi', 359),
#  ('padua', 350),
#  ('civitavecchia', 337),
#  ('rimini', 330),
#  ('viterbo', 314),
#  ('trani', 287),
# ...

# %%
List3 = [('pisa', 5074),
 ('como', 3579),
 ('lucca', 3257),
('asti', 2095),
 ('catania', 2067),
 ('bari', 1440),
 ('bergamo', 1238),
 ('perugia', 1227),
 ('genoa', 1138),
 ('salerno', 1066),
]
List3
# Out:
# [('pisa', 5074),
#  ('como', 3579),
#  ('lucca', 3257),
#  ('asti', 2095),
#  ('catania', 2067),
#  ('bari', 1440),
#  ('bergamo', 1238),
#  ('perugia', 1227),
#  ('genoa', 1138),
#  ('salerno', 1066)]

# %% [markdown]
# # 최종 List (10개 도시만)

# %%
List1_p = [('로마', 521),
 ('피렌체', 405),
 ('밀라노', 223),
 ('베네치아', 143),
 ('나폴리', 58),
 ('베로나', 50),
 ('볼로냐', 13),
 ('토리노', 10),
 ('라스페치아', 10),
 ('팔레르모', 7)]

List2_p = [('rome', 28191),
 ('venice', 18563),
 ('florence', 17927),
 ('milan', 10163),
 ('naples', 8899),
 ('siena', 5382),
 ('pisa', 5074),
 ('palermo', 3743),
 ('como', 3579),
 ('lucca', 3257)]

List3_p = [('pisa', 5074),
 ('como', 3579),
 ('lucca', 3257),
 ('asti', 2095),
 ('catania', 2067),
 ('bari', 1440),
 ('bergamo', 1238),
 ('perugia', 1227),
 ('genoa', 1138),
 ('salerno', 1066)]

print(List1_p)
print(List2_p)
print(List3_p)
# Out:
# [('로마', 521), ('피렌체', 405), ('밀라노', 223), ('베네치아', 143), ('나폴리', 58), ('베로나', 50), ('볼로냐', 13), ('토리노', 10), ('라스페치아', 10), ('팔레르모', 7)]
# [('rome', 28191), ('venice', 18563), ('florence', 17927), ('milan', 10163), ('naples', 8899), ('siena', 5382), ('pisa', 5074), ('palermo', 3743), ('como', 3579), ('lucca', 3257)]
# [('pisa', 5074), ('como', 3579), ('lucca', 3257), ('asti', 2095), ('catania', 2067), ('bari', 1440), ('bergamo', 1238), ('perugia', 1227), ('genoa', 1138), ('salerno', 1066)]
